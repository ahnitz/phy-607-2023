# %%
def f(x):
    return 500 *  (x - .1) * (x - .3) * (x - 5) * (x-.5) * (x-1.0) * (x - 1.5) * (x - 0.4)

# %%
import numpy
import numpy.random
from matplotlib import pyplot as plt

x = numpy.random.uniform(0, 1, 1000)
y = f(x) + numpy.random.normal(scale=1, size=1000)

pylab.scatter(x, y)

# %%
import h5py
f = h5py.File('./data.hdf', 'w')
f['data/xpos'] = x
f['data/ypos'] = y
f.close()
